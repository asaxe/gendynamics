# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e80957b1c454> in <module>()
# ----> 1 run_mnist.py
#
# NameError: name 'run_mnist' is not defined

# %%
# %run run_indep_gaussian.py
# Out:
#   File "/Users/asaxe/Documents/postdoctoralwork/gendynamics/code/run_indep_gaussian.py", line 45
#     if settings.batchsize > 0
#                              ^
# SyntaxError: invalid syntax

# %%
# %run run_indep_gaussian.py
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# dense_91 (Dense)                 (None, 50)            5050        dense_input_31[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 50)            0           dense_91[0][0]
# ____________________________________________________________________________________________________
# dense_92 (Dense)                 (None, 50)            2550        activation_11[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 50)            0           dense_92[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
# %run run_indep_gaussian.py
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# dense_112 (Dense)                (None, 50)            5050        dense_input_38[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 50)            0           dense_112[0][0]
# ____________________________________________________________________________________________________
# dense_113 (Dense)                (None, 50)            2550        activation_25[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, 50)            0           dense_113[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
epoch = np.linspace(0, len(history.history['loss']), len(history.history['loss']))

fig, ax = plt.subplots(1)
line1, = ax.plot(epoch, history.history['loss'], '--', linewidth=2,
                 label='Train loss')
line2, = ax.plot(epoch, history.history['val_loss'], '--', linewidth=2,
                 label='Test loss')
ax.legend(loc='upper center')
plt.show()

# %%
len(history.history['loss'])
# Out:
# 10000

# %%
history.history['loss']
# Out:
# [111.794677734375,
#  109.05437469482422,
#  106.49158477783203,
#  104.03866577148438,
#  101.64435577392578,
#  99.268402099609375,
#  96.87841796875,
#  94.448165893554688,
#  91.956474304199219,
#  89.387092590332031,
#  86.728538513183594,
#  83.974578857421875,
#  81.124786376953125,
#  78.184928894042969,
#  75.167434692382812,
#  72.091293334960938,
#  68.98138427734375,
#  65.867088317871094,
#  62.780128479003906,
#  59.751914978027344,
#  56.810829162597656,
#  53.97998046875,
#  51.275833129882812,
#  48.708061218261719,
#  46.280235290527344,
#  43.991268157958984,
#  41.836933135986328,
#  39.811119079589844,
#  37.906826019287109,
#  36.116607666015625,
#  34.432899475097656,
#  32.848129272460938,
#  31.3548583984375,
#  29.945888519287109,
#  28.614433288574219,
#  27.354221343994141,
#  26.159612655639648,
#  25.025623321533203,
#  23.947954177856445,
#  22.922945022583008,
#  21.947484970092773,
#  21.018957138061523,
#  20.135147094726562,
#  19.294151306152344,
# ...

# %%
history

# %%
history.history
# Out:
# {'acc': [0.10999999940395355,
#   0.10999999940395355,
#   0.15000000596046448,
#   0.20999999344348907,
#   0.25,
#   0.2800000011920929,
#   0.34999999403953552,
#   0.37000000476837158,
#   0.41999998688697815,
#   0.43999999761581421,
#   0.4699999988079071,
#   0.49000000953674316,
#   0.5,
#   0.49000000953674316,
#   0.49000000953674316,
#   0.5,
#   0.50999999046325684,
#   0.55000001192092896,
#   0.55000001192092896,
#   0.55000001192092896,
#   0.52999997138977051,
#   0.54000002145767212,
#   0.54000002145767212,
#   0.54000002145767212,
#   0.55000001192092896,
#   0.56999999284744263,
#   0.57999998331069946,
#   0.56999999284744263,
#   0.60000002384185791,
#   0.5899999737739563,
#   0.5899999737739563,
#   0.57999998331069946,
#   0.56999999284744263,
#   0.56999999284744263,
#   0.57999998331069946,
#   0.60000002384185791,
#   0.60000002384185791,
#   0.61000001430511475,
#   0.61000001430511475,
#   0.62000000476837158,
#   0.62000000476837158,
# ...

# %%
len(history.history['acc'])
# Out:
# 10000
